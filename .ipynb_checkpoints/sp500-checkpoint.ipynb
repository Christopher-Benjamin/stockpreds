# %%
import yfinance as yf
import pandas as pd

# %%
# !pip3 install numpy
# Out:
# Requirement already satisfied: numpy in /Users/crispy/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (2.3.3)

# %%
import sys

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")

# %%
del sp500["Dividends"]

# %%
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)
#target is "1" if tomorrow's price increased and "0" if it decreased

# %%
#removes all rows before Jan 1, 1990
sp500 = sp500.loc["1985-01-01":].copy()

# %%
#!pip install --upgrade --force-reinstall numpy scipy scikit-learn

# %%
sp500.index = sp500.index.tz_localize(None)

# %%
sp500 = sp500.copy()

# %%
# 1) Make sure sp500 index is DatetimeIndex (daily)
sp500 = sp500.copy()
if not isinstance(sp500.index, pd.DatetimeIndex):
    sp500 = sp500.set_index(pd.to_datetime(sp500["Date"]))

# 2) Download VIX (^VIX) for the same date span
import yfinance as yf
vix_raw = yf.download("^VIX",
                      start=sp500.index.min().date(),
                      end=(sp500.index.max() + pd.Timedelta(days=1)).date(),
                      progress=False, auto_adjust=False)

# %%
# Take the close as a Series and clean the index tz
vix_series = vix_raw[["Close"]].squeeze().rename("VIX").copy()
vix_series.index = pd.to_datetime(vix_series.index).tz_localize(None)

sp500.index = pd.to_datetime(sp500.index).tz_localize(None)
sp500["VIX"] = vix_series.reindex(sp500.index)

# %%
# 3) Create VIX features
sp500 = sp500.copy()  # silence SettingWithCopy warnings if sp500 was sliced earlier
sp500.loc[:, "VIX_Lag1"]    = sp500["VIX"].shift(1)
sp500.loc[:, "VIX_Change"]  = sp500["VIX"].pct_change(fill_method=None)
sp500.loc[:, "VIX_5d"]      = sp500["VIX"].rolling(5, min_periods=1).mean()
sp500.loc[:, "VIX_21d_vol"] = sp500["VIX"].pct_change(fill_method=None).rolling(21).std()

# %%
# 1) Standardized "fear sentiment" — how many std devs above/below the mean VIX is
sp500 = sp500.copy()
sp500["Fear_Zscore"] = (
    (sp500["VIX"] - sp500["VIX"].rolling(252, min_periods=20).mean()) /
    sp500["VIX"].rolling(252, min_periods=20).std()
)

# 2) Binary indicator — market in "fear" mode (VIX > 20)
sp500["Fear_High"] = (sp500["VIX"] > 20).astype(int)

# 3) Short-term vs long-term volatility difference
sp500["Fear_STLT_diff"] = (
    sp500["VIX"].rolling(5, min_periods=1).mean() -
    sp500["VIX"].rolling(252, min_periods=20).mean()
)

# %%
horizons = [2,5,60,250,1000]
fear_features = ["Fear_Zscore", "Fear_High", "Fear_STLT_diff"]
predictors3 = []
predictors3.extend(fear_features)

for horizon in horizons:
    rolling_average = sp500.rolling(horizon).mean()

    ratio_column = f"Close_Ratio_{horizon}"
    sp500.loc[:, ratio_column] = sp500["Close"] / rolling_average["Close"]

    trend_column = f"Trend_{horizon}"
    sp500.loc[:, trend_column] = sp500["Target"].shift(1).rolling(horizon).sum()

    predictors3 += [ratio_column, trend_column]

# %%
sp500 = sp500.dropna()

# %%
import sklearn

# %%
import numpy as np


from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

# Prepare data
predictors = ["Close", "Volume", "Open", "High", "Low"]
predictors += predictors3

df = sp500.dropna(subset=predictors + ["Target"]).copy()
X = df[predictors].values
y = df["Target"].values

# Final holdout
HOLDOUT = 250
X_train, y_train = X[:-HOLDOUT], y[:-HOLDOUT]
X_test,  y_test  = X[-HOLDOUT:], y[-HOLDOUT:]

# Time-aware CV
tscv = TimeSeriesSplit(n_splits=5)

# RF tuning
rf = RandomForestClassifier(random_state=1, n_jobs=-1)
param_grid = {
    "n_estimators": [120, 180, 300],
    "min_samples_split": [25, 50, 75, 100],
    "max_depth": [None, 8, 12],
}
gcv = GridSearchCV(rf, param_grid, cv=tscv, scoring="precision", n_jobs=-1, refit=True)
gcv.fit(X_train, y_train)
best_rf = gcv.best_estimator_
print("Best RF params:", gcv.best_params_)

# Logistic baseline
logit = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", LogisticRegression(max_iter=500, solver="lbfgs"))
])
logit.fit(X_train, y_train)

# Threshold sweep on holdout
def threshold_sweep(model, X_te, y_te, thresholds=np.arange(0.50, 0.71, 0.02)):
    p = model.predict_proba(X_te)[:, 1]
    rows = []
    for t in thresholds:
        yhat = (p >= t).astype(int)
        rows.append({
            "threshold": float(t),
            "precision": float(precision_score(y_te, yhat, zero_division=0)),
            "recall": float(recall_score(y_te, yhat, zero_division=0)),
            "f1": float(f1_score(y_te, yhat, zero_division=0)),
        })
    return pd.DataFrame(rows).sort_values("precision", ascending=False)

rf_sweep = threshold_sweep(best_rf, X_test, y_test)
lg_sweep = threshold_sweep(logit,   X_test, y_test)

print("\nRandomForest holdout sweep (sorted by precision):")
display(rf_sweep.head(10))
print("\nLogistic baseline holdout sweep (sorted by precision):")
display(lg_sweep.head(10))


THRESH = 0.60
def eval_at_threshold(model, X_te, y_te, t=THRESH):
    p = model.predict_proba(X_te)[:, 1]
    yhat = (p >= t).astype(int)
    return {
        "threshold": t,
        "precision": precision_score(y_te, yhat, zero_division=0),
        "recall": recall_score(y_te, yhat, zero_division=0),
        "f1": f1_score(y_te, yhat, zero_division=0),
        "confusion_matrix": confusion_matrix(y_te, yhat).tolist(),
    }

print("\nRF @ 0.60:", eval_at_threshold(best_rf, X_test, y_test, THRESH))
print("Logit @ 0.60:", eval_at_threshold(logit,   X_test, y_test, THRESH))
# Out:
# Best RF params: {'max_depth': 8, 'min_samples_split': 100, 'n_estimators': 120}
#
# RandomForest holdout sweep (sorted by precision):
#    threshold  precision    recall        f1
# 2       0.54   0.580000  0.204225  0.302083
# 0       0.50   0.572165  0.781690  0.660714
# 1       0.52   0.555556  0.563380  0.559441
# 3       0.56   0.375000  0.021127  0.040000
# 4       0.58   0.000000  0.000000  0.000000
# 5       0.60   0.000000  0.000000  0.000000
# 6       0.62   0.000000  0.000000  0.000000
# 7       0.64   0.000000  0.000000  0.000000
# 8       0.66   0.000000  0.000000  0.000000
# 9       0.68   0.000000  0.000000  0.000000
# Logistic baseline holdout sweep (sorted by precision):
#    threshold  precision    recall        f1
# 5       0.60   1.000000  0.042254  0.081081
# 6       0.62   1.000000  0.007042  0.013986
# 4       0.58   0.620690  0.126761  0.210526
# 3       0.56   0.597403  0.323944  0.420091
# 0       0.50   0.571429  0.985915  0.723514
# 1       0.52   0.566038  0.845070  0.677966
# 2       0.54   0.551020  0.570423  0.560554
# 7       0.64   0.000000  0.000000  0.000000
# 8       0.66   0.000000  0.000000  0.000000
# 9       0.68   0.000000  0.000000  0.000000
# RF @ 0.60: {'threshold': 0.6, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'confusion_matrix': [[108, 0], [142, 0]]}
# Logit @ 0.60: {'threshold': 0.6, 'precision': 1.0, 'recall': 0.04225352112676056, 'f1': 0.08108108108108109, 'confusion_matrix': [[108, 0], [136, 6]]}

# %%
sp500 = sp500.dropna()

# %%
def predict(train, test, predictors, model, threshold=0.60):
    model.fit(train[predictors], train["Target"])
    proba = model.predict_proba(test[predictors])[:, 1]
    out = test[["Target"]].copy()
    out["Proba"] = proba
    out["Predictions"] = (proba >= threshold).astype(int)
    return out

# %%
def backtest(data, model, predictors, start=3000, step=250): #start=2500 means train the first model with 10 years of data
    all_predictions = []
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
TUNED_RF = best_rf     
THRESH   = 0.60        # threshold for percent certainty that the S&P will go up/down

def backtest_with_threshold(data, model, predictors, start=3000, step=250, threshold=THRESH):
    all_preds = []
    for i in range(start, data.shape[0], step):
        train = data.iloc[:i].dropna(subset=predictors + ["Target"]).copy()
        test  = data.iloc[i:(i+step)].dropna(subset=predictors + ["Target"]).copy()
        if len(test) == 0 or len(train) == 0:
            continue
        preds = predict(train, test, predictors, model, threshold=threshold)
        all_preds.append(preds)
    if not all_preds:
        return pd.DataFrame(columns=["Target", "Proba", "Predictions"])
    return pd.concat(all_preds, axis=0)

# %%
bt_preds = backtest_with_threshold(sp500, TUNED_RF, predictors, start=3000, step=250, threshold=THRESH)

from sklearn.metrics import precision_score
precision_score(bt_preds["Target"], bt_preds["Predictions"])
# Out:
# 0.5467980295566502

# %%
predictors
# Out:
# ['Close',
#  'Volume',
#  'Open',
#  'High',
#  'Low',
#  'Fear_Zscore',
#  'Fear_High',
#  'Fear_STLT_diff',
#  'Close_Ratio_2',
#  'Trend_2',
#  'Close_Ratio_5',
#  'Trend_5',
#  'Close_Ratio_60',
#  'Trend_60',
#  'Close_Ratio_250',
#  'Trend_250',
#  'Close_Ratio_1000',
#  'Trend_1000']

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1990-01-31   322.980011   329.079987   322.980011   329.079987   189660000
# 1990-02-01   329.079987   329.859985   327.760010   328.790009   154580000
# 1990-02-02   328.790009   332.100006   328.089996   330.920013   164400000
# 1990-02-05   330.920013   332.160004   330.450012   331.850006   130950000
# 1990-02-06   331.850006   331.859985   328.200012   329.660004   134070000
# ...                 ...          ...          ...          ...         ...
# 2025-10-03  6722.140137  6750.870117  6705.669922  6715.790039  5713110000
# 2025-10-06  6733.859863  6749.520020  6717.779785  6740.279785  5604460000
# 2025-10-07  6746.140137  6754.490234  6699.959961  6714.589844  5546150000
# 2025-10-08  6723.870117  6755.640137  6718.089844  6753.720215  5383130000
# 2025-10-09  6760.500000  6764.580078  6716.169922  6735.109863  5385020000
#
#                Tomorrow  Target        VIX   VIX_Lag1  VIX_Change  ...  \
# Date                                                               ...
# 1990-01-31   328.790009       0  25.360001  27.250000   -0.069358  ...
# 1990-02-01   330.920013       1  24.870001  25.360001   -0.019322  ...
# 1990-02-02   331.850006       1  24.320000  24.870001   -0.022115  ...
# 1990-02-05   329.660004       0  24.540001  24.320000    0.009046  ...
# 1990-02-06   333.750000       1  24.690001  24.540001    0.006112  ...
# ...                 ...     ...        ...        ...         ...  ...
# 2025-10-03  6740.279785       1  16.650000  16.629999    0.001203  ...
# 2025-10-06  6714.589844       0  16.370001  16.650000   -0.016817  ...
# 2025-10-07  6753.720215       1  17.240000  16.370001    0.053146  ...
# 2025-10-08  6735.109863       0  16.299999  17.240000   -0.054524  ...
# 2025-10-09  6552.509766       0  16.430000  16.299999    0.007976  ...
#
#             Close_Ratio_2  Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 1990-01-31       1.009355      1.0       1.009981      1.0        0.959505
# 1990-02-01       0.999559      1.0       1.007415      1.0        0.958837
# 1990-02-02       1.003229      1.0       1.010770      2.0        0.965231
# 1990-02-05       1.001403      2.0       1.009510      3.0        0.968240
# 1990-02-06       0.996689      1.0       0.998788      3.0        0.962174
# ...                   ...      ...            ...      ...             ...
# 2025-10-03       1.000033      2.0       1.002596      5.0        1.039023
# 2025-10-06       1.001820      2.0       1.003882      5.0        1.041522
# 2025-10-07       0.998091      1.0       0.999278      4.0        1.036362
# 2025-10-08       1.002905      1.0       1.003831      4.0        1.041035
# 2025-10-09       0.998620      1.0       1.000477      3.0        1.036911
#
#             Trend_60  Close_Ratio_250  Trend_250  Close_Ratio_1000  Trend_1000
# Date
# 1990-01-31      32.0         1.003247      141.0          1.168535       560.0
# 1990-02-01      32.0         1.001963      141.0          1.167054       560.0
# 1990-02-02      32.0         1.008069      141.0          1.174161       560.0
# 1990-02-05      32.0         1.010493      142.0          1.177013       560.0
# 1990-02-06      32.0         1.003414      142.0          1.168809       560.0
# ...              ...              ...        ...               ...         ...
# 2025-10-03      35.0         1.118160      143.0          1.377161       532.0
# 2025-10-06      36.0         1.121499      143.0          1.381509       533.0
# 2025-10-07      35.0         1.116467      143.0          1.375577       533.0
# 2025-10-08      36.0         1.122225      143.0          1.382916       533.0
# 2025-10-09      35.0         1.118432      142.0          1.378457       532.0
#
# [8989 rows x 25 columns]
